# %% [markdown]
# <a href="https://colab.research.google.com/github/ChikoAbillaBasya/PCVK25_3G_09/blob/main/Week1_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **D2. Pengenalan Python untuk membaca dan menampilkan image dengan
# pengenalan macam-macam Library (Numpy, pandas, cv2, skimage, PIL dan
# matplotlib)**

# %% [markdown]
# 1. Gunakan beberapa library berikut sebagai langkah pertama:

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow  # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# 2. Langkah 2 untuk membaca dan menampilkan image

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
     "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
    "https://avatars.githubusercontent.com/u/143988659?v=4"]
# Baca dan tampilkan image
# loop pada tiap url image beberapa image dapat disimpan pada list
for url in urls:
    image = io.imread(url)                                #read image
    image = cv.resize(image, (0,0), fx=0.5, fy=0.5)       #resize image to half size
    image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)        #convert color to RGB
    final_frame = cv.hconcat((image, image_2))            #concatenate image
    cv2_imshow(final_frame)                               #show image
    print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=460x230>

# %% [markdown]
# 3. Langkah 3 pada praktikum ini adalah melihat ukuran file image, dengan cara
# sebagai berikut:

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  230  x  230
# <PIL.Image.Image image mode=RGB size=230x230>

# %% [markdown]
# 4. Langkah 4 berikut digunakan untuk mengakses pixel dengan memberikan
# garis horizontal berwarna putih di tengah image

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis horizontal ditengah image
for y in range(lebar):
    image_3[int((tinggi)/2), y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=460x230>

# %% [markdown]
# **PERTANYAAN PRAKTIKUM D2**

# %% [markdown]
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Colab?
#
# Jawab :
#
# Karena dengan menggunakan Colab tidak perlu instalasi Python dan library di laptop masing-masing, gratis, serta memudahkan kolaborasi dan penyimpanan melalui Google Drive/GitHub.
#
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan? Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
#
# Jawab:
#
# a. OpenCV (cv2) → dipakai untuk membuka file gambar, melakukan pengolahan citra (resize, konversi warna, dsb.), serta menampilkannya kembali.
#
# b. NumPy → digunakan untuk operasi numerik pada data citra karena gambar disimpan dalam bentuk array pixel.
#
# c. Matplotlib → berfungsi men-plot atau men-visualisasikan gambar hasil pemrosesan dalam notebook.
#
# d. skimage.io (io) → bisa digunakan sebagai alternatif untuk membaca gambar langsung dari alamat URL.
#
# e. google.colab.patches.cv2_imshow → tool khusus di Colab agar gambar dari OpenCV bisa tampil dengan benar pada output notebook.
#
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :

# %%
image = cv.resize(image, (0,0), fx=0.5, fy=0.5)

# %% [markdown]
# Apa kegunaan kode program tersebut? dan apa pengaruhnya jika tidak dilakukan?
#
# Jawab:
#
# Kode cv.resize(image, (0,0), fx=0.5, fy=0.5) adalah fungsi OpenCV untuk mengubah ukuran gambar, di mana (0,0) menandakan ukuran target tidak ditentukan secara langsung, melainkan mengikuti faktor skala fx=0.5 dan fy=0.5, sehingga lebar dan tinggi gambar diperkecil menjadi setengah dari ukuran aslinya.
#
# 4. Perhatikan potongan kode progam berikut :

# %%
  #membuat garis horizontal ditengah image
  for y in range(lebar):
      image_3[int((tinggi)/2), y] = [255, 255, 255]

# %% [markdown]
# Apakah kegunaan kode [255,255,255] ? Jelaskan!
#
# Jawab:
#
# [255,255,255] adalah representasi warna putih dalam format BGR (Blue, Green, Red). Nilai maksimal 255 pada semua channel menghasilkan warna putih.
#
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun
# rendah!
#
# Jawab:
#
# a. Pixel merupakan unit terkecil dari citra digital yang merepresentasikan satu titik warna.
#
# b. Resolusi menunjukkan jumlah keseluruhan pixel dalam sebuah citra, misalnya resolusi 1920×1080 berarti ada 1920 titik horizontal dan 1080 titik vertikal.
#
# c. Jika resolusi tinggi, maka jumlah pixel lebih banyak sehingga detail gambar tampak jelas dan tajam.
#
# d. Jika resolusi rendah, jumlah pixel lebih sedikit sehingga gambar terlihat kabur atau pecah saat diperbesar.

# %% [markdown]
# **TUGAS PRAKTIKUM 2**

# %% [markdown]
# 1. Lakukan langkah-langkah praktikum seperti diatas
# 2. Buat garis vertikal dan garis menyilang diagonal pada image keluaran

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis vertikal ditengah image
for x in range(tinggi):
    image_3[x, int((lebar)/2)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=460x230>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis menyilang (X) di tengah image
for x in range(tinggi):
    for y in range(lebar):
        if x == y:
            image_3[x, y] = [255, 255, 255]
        if x + y == lebar - 1:
            image_3[x, y] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=460x230>

# %% [markdown]
# 3. Buat garis horisontal berwarna putih dibagian tengah gambar dengan
# panjang tertentu

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

tinggi, lebar = image.shape[:2]

panjang = 100

y_tengah = tinggi // 2
x_awal = (lebar // 2) - (panjang // 2)
x_akhir = (lebar // 2) + (panjang // 2)

# membuat garis horizontal putih dengan panjang tertentu
for x in range(x_awal, x_akhir):
    image_3[y_tengah, x] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=460x230>

# %% [markdown]
# 4. Buat kotak menggunakan kumpulan pixel warna putih di sembarang tempat
# dalam gambar

# %%
import random

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

tinggi, lebar = image.shape[:2]

kotak_tinggi = 80
kotak_lebar = 80

y_awal = random.randint(0, tinggi - kotak_tinggi)
x_awal = random.randint(0, lebar - kotak_lebar)

# gambar kotak putih pakai kumpulan pixel
for y in range(y_awal, y_awal + kotak_tinggi):
    for x in range(x_awal, x_awal + kotak_lebar):
        image_3[y, x] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=460x230>
